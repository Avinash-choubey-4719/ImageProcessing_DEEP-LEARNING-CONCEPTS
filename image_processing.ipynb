# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('coding.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img)
# Out:
# [[[ 20  24  33]
#   [ 20  24  33]
#   [ 20  24  33]
#   ...
#   [104  44  44]
#   [104  44  44]
#   [104  44  44]]
#
#  [[ 20  24  33]
#   [ 20  24  33]
#   [ 20  24  33]
#   ...
#   [104  44  44]
#   [104  44  44]
#   [104  44  44]]
#
#  [[ 20  24  33]
#   [ 20  24  33]
#   [ 20  24  33]
#   ...
#   [104  44  44]
#   [104  44  44]
#   [105  45  45]]
#
#  ...
#
#  [[ 81 153 203]
#   [ 80 152 202]
#   [ 80 152 202]
#   ...
#   [ 80  38  40]
#   [ 80  38  40]
#   [ 80  38  40]]
#
#  [[ 81 153 203]
#   [ 80 152 202]
#   [ 79 151 201]
#   ...
#   [ 79  37  39]
#   [ 79  37  39]
#   [ 80  38  40]]
#
#  [[ 81 153 203]
#   [ 81 153 203]
#   [ 78 150 200]
#   ...
#   [ 79  37  39]
#   [ 79  37  39]
#   [ 80  38  40]]]

# %%
show = plt.imshow(img)
plt.show()

# %%
show = plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (533, 800, 3)

# %%
from PIL import Image

# %%
img = Image.open('coding.jpg')

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x533 at 0x7F46A013DE48>

# %%
show = plt.imshow(img)
plt.show()

# %%
resized_image = img.resize((200, 200))

# %%
show = plt.imshow(resized_image)
plt.show()

# %%
img.save('codingImage.jpg')

# %%
img = plt.imread('codingImage.jpg')

# %%
img.shape
# Out:
# (533, 800, 3)

# %%
import cv2

# %%
img = cv2.imread('coding.jpg')

# %%
img
# Out:
# array([[[ 33,  24,  20],
#         [ 33,  24,  20],
#         [ 33,  24,  20],
#         ...,
#         [ 44,  44, 104],
#         [ 44,  44, 104],
#         [ 44,  44, 104]],
#
#        [[ 33,  24,  20],
#         [ 33,  24,  20],
#         [ 33,  24,  20],
#         ...,
#         [ 44,  44, 104],
#         [ 44,  44, 104],
#         [ 44,  44, 104]],
#
#        [[ 33,  24,  20],
#         [ 33,  24,  20],
#         [ 33,  24,  20],
#         ...,
#         [ 44,  44, 104],
#         [ 44,  44, 104],
#         [ 45,  45, 105]],
#
#        ...,
#
#        [[203, 153,  81],
#         [202, 152,  80],
#         [202, 152,  80],
#         ...,
#         [ 40,  38,  80],
#         [ 40,  38,  80],
#         [ 40,  38,  80]],
#
#        [[203, 153,  81],
#         [202, 152,  80],
#         [201, 151,  79],
#         ...,
#         [ 39,  37,  79],
#         [ 39,  37,  79],
#         [ 40,  38,  80]],
#
#        [[203, 153,  81],
#         [203, 153,  81],
#         [200, 150,  78],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (533, 800, 3)
